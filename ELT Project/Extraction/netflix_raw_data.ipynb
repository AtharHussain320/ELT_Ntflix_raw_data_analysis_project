# %%
#%pip install pandas
#%pip install sqlalchemy
#pip install pyodbc

# %%
import pandas as pd 
df = pd.read_csv('netflix_titles.csv')

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql+pyodbc://DESKTOP-KFVQIG5/master?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes')
conn = engine.connect()

# %%
df.to_sql('netflix_raw', con=conn , index=False, if_exists = 'append')
conn.close()
